# %%
 #coding=utf-8
from numpy import *

def loadDataSet():
     dataMat = []
     labelMat = []
     fr = open('testSet.txt')
     for line in fr.readlines():
         lineArr = line.strip().split()
         dataMat.append([1.0, float(lineArr[0]), float(lineArr[1])])
         labelMat.append(int(lineArr[2]))
     return dataMat, labelMat
     
 def sigmoid(inX):
     return 1.0/(1+exp(-inX))
     
 def gradAscend(dataMatIn, classLabels):
     dataMatrix = mat(dataMatIn)
     labelMat = mat(classLabels).transpose()
     m,n = shape(dataMatrix)
     alpha = 0.001
     maxCycle = 500
     weight = ones((n,1))
     for k in range(maxCycle):
         h = sigmoid(dataMatrix*weight)
         error = labelMat - h
         weight += alpha * dataMatrix.transpose() * error
         #plotBestFit(weight)
     return weight
 
 def gradAscendWithDraw(dataMatIn, classLabels):
     import matplotlib.pyplot as plt
     fig = plt.figure()
     ax = fig.add_subplot(311,ylabel='x0')
     bx = fig.add_subplot(312,ylabel='x1')
     cx = fig.add_subplot(313,ylabel='x2')
     dataMatrix = mat(dataMatIn)
     labelMat = mat(classLabels).transpose()
     m,n = shape(dataMatrix)
     alpha = 0.001
     maxCycle = 500
     weight = ones((n,1))
     wei1 = []
     wei2 = []
     wei3 = []
     for k in range(maxCycle):
         h = sigmoid(dataMatrix*weight)
         error = labelMat - h
         weight += alpha * dataMatrix.transpose() * error
         wei1.extend(weight[0])
         wei2.extend(weight[1])
         wei3.extend(weight[2])
     ax.plot(range(maxCycle), wei1)
     bx.plot(range(maxCycle), wei2)
     cx.plot(range(maxCycle), wei3)
     plt.xlabel('iter_num')
     plt.show()
     return weight

 def stocGradAscent0(dataMatrix, classLabels):
     m,n = shape(dataMatrix)
     
     alpha = 0.001
     weight = ones(n)
     for i in range(m):
         h = sigmoid(sum(dataMatrix[i]*weight))
         error = classLabels[i] - h
         weight = weight + alpha * error * dataMatrix[i]
     return weight
     
 def stocGradAscentWithDraw0(dataMatrix, classLabels):
     import matplotlib.pyplot as plt
     fig = plt.figure()
     ax = fig.add_subplot(311,ylabel='x0')
     bx = fig.add_subplot(312,ylabel='x1')
     cx = fig.add_subplot(313,ylabel='x2')
     m,n = shape(dataMatrix)
     
     alpha = 0.001
     weight = ones(n)
     wei1 = array([])
     wei2 = array([])
     wei3 = array([])
     numIter = 200
     for j in range(numIter):
         for i in range(m):
             h = sigmoid(sum(dataMatrix[i]*weight))
             error = classLabels[i] - h
             weight = weight + alpha * error * dataMatrix[i]
             wei1 =append(wei1, weight[0])
             wei2 =append(wei2, weight[1])
             wei3 =append(wei3, weight[2])
     ax.plot(array(range(m*numIter)), wei1)
     bx.plot(array(range(m*numIter)), wei2)
     cx.plot(array(range(m*numIter)), wei3)
     plt.xlabel('iter_num')
     plt.show()
     return weight
    
 def stocGradAscent1(dataMatrix, classLabels, numIter=150):
     m,n = shape(dataMatrix)
     
     #alpha = 0.001
     weight = ones(n)
     for j in range(numIter):
         dataIndex = range(m)
         for i in range(m):
             alpha = 4/ (1.0+j+i) +0.01
             randIndex = int(random.uniform(0,len(dataIndex)))
             h = sigmoid(sum(dataMatrix[randIndex]*weight))
             error = classLabels[randIndex] - h
             weight = weight + alpha * error * dataMatrix[randIndex]
             del(dataIndex[randIndex])
     return weight
     
 def stocGradAscentWithDraw1(dataMatrix, classLabels, numIter=150):
     import matplotlib.pyplot as plt
     fig = plt.figure()
     ax = fig.add_subplot(311,ylabel='x0')
     bx = fig.add_subplot(312,ylabel='x1')
     cx = fig.add_subplot(313,ylabel='x2')
     m,n = shape(dataMatrix)
     
     #alpha = 0.001
     weight = ones(n)
     wei1 = array([])
     wei2 = array([])
     wei3 = array([])
     for j in range(numIter):
         dataIndex = range(m)
         for i in range(m):
             alpha = 4/ (1.0+j+i) +0.01
             randIndex = int(random.uniform(0,len(dataIndex)))
             h = sigmoid(sum(dataMatrix[randIndex]*weight))
             error = classLabels[randIndex] - h
             weight = weight + alpha * error * dataMatrix[randIndex]
             del(dataIndex[randIndex])
             wei1 =append(wei1, weight[0])
             wei2 =append(wei2, weight[1])
             wei3 =append(wei3, weight[2])
     ax.plot(array(range(len(wei1))), wei1)
     bx.plot(array(range(len(wei2))), wei2)
     cx.plot(array(range(len(wei2))), wei3)
     plt.xlabel('iter_num')
     plt.show()
     return weight
     
 def plotBestFit(wei):
     import matplotlib.pyplot as plt
     weight = wei
     dataMat,labelMat = loadDataSet()
     dataArr = array(dataMat)
     n = shape(dataArr)[0]
     xcord1 = []
     ycord1 = []
     xcord2 = []
     ycord2 = []
     for i in range(n):
         if int(labelMat[i]) == 1:
             xcord1.append(dataArr[i,1])
             ycord1.append(dataArr[i,2])
         else:
             xcord2.append(dataArr[i,1])
             ycord2.append(dataArr[i,2])
     fig = plt.figure()
     ax = fig.add_subplot(111)
     ax.scatter(xcord1, ycord1, s=30, c='red', marker='s')
     ax.scatter(xcord2, ycord2, s=30, c='green')
     x = arange(-3.0, 3.0, 0.1)
     y = (-weight[0] - weight[1]*x)/weight[2]
     ax.plot(x,y)
     plt.xlabel('X1')
     plt.ylabel('X2')
     plt.show()
     
 def main():
     dataArr,labelMat = loadDataSet()
     #w = gradAscendWithDraw(dataArr,labelMat)
     w = stocGradAscentWithDraw0(array(dataArr),labelMat)
     plotBestFit(w)

 if __name__ == '__main__':
     main()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-e81401ea9a69> in <module>()
#     181
#     182 if __name__ == '__main__':
# --> 183     main()
#
# <ipython-input-2-e81401ea9a69> in main()
#     175
#     176 def main():
# --> 177     dataArr,labelMat = loadDataSet()
#     178     #w = gradAscendWithDraw(dataArr,labelMat)
#     179     w = stocGradAscentWithDraw0(array(dataArr),labelMat)
#
# <ipython-input-2-e81401ea9a69> in loadDataSet()
#       5     dataMat = []
#       6     labelMat = []
# ----> 7     fr = open('testSet.txt')
#       8     for line in fr.readlines():
#       9         lineArr = line.strip().split()
#
# IOError: [Errno 2] No such file or directory: 'testSet.txt'

# %%
 #coding=utf-8
'''
#iris datasets
150,4,setosa,versicolor,virginica
5.1,3.5,1.4,0.2,0
7.0,3.2,4.7,1.4,1
6.3,3.3,6.0,2.5,2
'''
from numpy import *   
from sklearn.datasets import load_iris     # import datasets  
  
# load the dataset: iris  
iris = load_iris()   
samples = iris.data  
samples.reshape(-1,1)
#print samples   
target = iris.target   
# import the LogisticRegression  
from sklearn.linear_model import LogisticRegression   
  
classifier = LogisticRegression()  # 使用类，参数全是默认的  
classifier.fit(samples, target)  # 训练数据来学习，不需要返回值  
  
y = classifier.predict([5, 3, 5, 2.5])  # 测试数据，分类返回标记  
score = classifier.score(samples, target)
print score
print y
iris

#iris.data
#iris.data.shape
#iris.DESCR
#iris.target
#iris.target_namee
#iris.feature_names
#拆分数据集为训练集和测试集
from sklearn import cross_validation
x_train, x_test, y_train, y_test = cross_validation.train_test_split(iris.data, iris.target, test_size=0.2, random_state=0)
classifier.fit(x_train, y_train)
score = classifier.score(x_test, y_test)
print "test set score %s" % score


#
print classifier.predict_proba(x_test)
print classifier.predict_log_proba(x_test)

#绘图
import matplotlib.pyplot as plt
plt.plot([1,2,3,7]) #plot默认参数为y的值，
plt.show()
plt.plot([1,2,3,4], [5,5,7,8])
plt.ylabel("yValue")
plt.xlabel("xVlaue")
plt.show()
plt.plot([1,2,3,4], [1,4,9,16], 'ro')#'b-' 'ro' 'r--' 'bs' 'g^'
plt.axis([0, 6, 0, 20])
plt.show()
# evenly sampled time at 200ms intervals
import numpy as np
t = np.arange(0., 5., 0.2)  #开始，终值，步长
np.linspace(0, 1, 12)       #开始，终值，元素个数  按等差生成
np.logspace(0, 2, 20)       #开始，终值，元素个数  按等比生成
# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()
# Out:
# D:\Program\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# 0.96
# [2]
# test set score 0.966666666667
# [[  8.48551777e-04   1.75187088e-01   8.23964360e-01]
#  [  2.55349832e-02   8.28280027e-01   1.46184990e-01]
#  [  9.38770402e-01   6.12219632e-02   7.63524745e-06]
#  [  1.95595855e-04   3.92858391e-01   6.06946013e-01]
#  [  8.59320284e-01   1.40622105e-01   5.76113536e-05]
#  [  2.66875251e-04   1.55252833e-01   8.44480292e-01]
#  [  8.95117125e-01   1.04841756e-01   4.11191018e-05]
#  [  2.35243207e-02   6.58831216e-01   3.17644464e-01]
#  [  1.08833116e-02   6.98823212e-01   2.90293477e-01]
#  [  7.00413669e-02   7.49572383e-01   1.80386250e-01]
#  [  5.20656908e-04   4.20959554e-01   5.78519789e-01]
#  [  4.26710447e-02   6.21482821e-01   3.35846134e-01]
#  [  1.09432076e-02   6.34645730e-01   3.54411062e-01]
#  [  1.40712441e-02   6.19260220e-01   3.66668536e-01]
#  [  1.06714217e-02   5.32156800e-01   4.57171779e-01]
#  [  8.01498547e-01   1.98425468e-01   7.59849427e-05]
#  [  1.58451196e-02   5.00866210e-01   4.83288670e-01]
#  [  1.09602570e-02   5.46972426e-01   4.42067317e-01]
#  [  8.24055133e-01   1.75813438e-01   1.31429015e-04]
#  [  9.34975332e-01   6.50079773e-02   1.66902688e-05]
#  [  1.78835012e-03   2.28891901e-01   7.69319749e-01]
#  [  1.39733319e-02   3.91262506e-01   5.94764162e-01]
#  [  8.33127288e-01   1.66673090e-01   1.99622130e-04]
#  [  8.02515862e-01   1.97263757e-01   2.20381321e-04]
#  [  4.20259357e-03   3.50295229e-01   6.45502177e-01]
#  [  9.16674110e-01   8.32985891e-02   2.73009505e-05]
#  [  9.04522738e-01   9.53562383e-02   1.21023889e-04]
#  [  4.09428633e-02   7.21434502e-01   2.37622635e-01]
#  [  1.04601639e-01   7.38723497e-01   1.56674863e-01]
#  [  8.76397457e-01   1.23484743e-01   1.17799937e-04]]
# [[ -7.07197945  -1.7419008   -0.193628  ]
#  [ -3.66770588  -0.18840398  -1.92288241]
#  [ -0.06318434  -2.79324928 -11.78273521]
#  [ -8.53945999  -0.93430606  -0.49931543]
#  [ -0.15161357  -1.9616791   -9.7617909 ]
#  [ -8.22872923  -1.86270031  -0.16903388]
#  [ -0.1108007   -2.25530315 -10.09903778]
#  [ -3.74972047  -0.4172879   -1.14682256]
#  [ -4.52052471  -0.35835748  -1.23686288]
#  [ -2.65866926  -0.28825239  -1.7126549 ]
#  [ -7.56041926  -0.86521852  -0.54728253]
#  [ -3.1542347   -0.47564701  -1.09110216]
#  [ -4.51503633  -0.45468834  -1.03729785]
#  [ -4.26362199  -0.47922971  -1.00329701]
#  [ -4.54018598  -0.6308171   -0.78269608]
#  [ -0.22127212  -1.61734173  -9.48497536]
#  [ -4.14489374  -0.69141626  -0.72714114]
#  [ -4.51347955  -0.60335689  -0.81629311]
#  [ -0.19351784  -1.73833186  -8.93704366]
#  [ -0.06723513  -2.73324529 -11.00068471]
#  [ -6.3264618   -1.47450544  -0.2622486 ]
#  [ -4.27060463  -0.93837657  -0.51959032]
#  [ -0.18256884  -1.79172093  -8.51908433]
#  [ -0.22000366  -1.62321358  -8.42015124]
#  [ -5.47205343  -1.04897897  -0.4377267 ]
#  [ -0.08700326  -2.48532367 -10.50858904]
#  [ -0.10034784  -2.35013552  -9.0195226 ]
#  [ -3.19557776  -0.32651369  -1.43707143]
#  [ -2.25759605  -0.30283159  -1.85358255]
#  [ -0.13193557  -2.09163767  -9.04652283]]

# %%
'''
index - 索引名
q - 查询指定匹配 使用Lucene查询语法
from_ - 查询起始点  默认0
doc_type - 文档类型
size - 指定查询条数 默认10
field - 指定字段 逗号分隔
sort - 排序  字段：asc/desc
body - 使用Query DSL
scroll - 滚动查询
 '''
from elasticsearch import Elasticsearch
es = Elasticsearch([{'host':'10.252.145.166','port':9200}])
es.search(index='dbwww58com', body={'query':{'match':{'content':'张艺兴'}}})

#ndarray 数据类型构建
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'hits': {u'hits': [{u'_id': u'2930962',
#     u'_index': u'dbwww58com',
#     u'_score': 129.552,
#     u'_source': {u'@timestamp': u'2016-12-20T07:13:08.603Z',
#      u'@version': u'1',
#      u'addtime': u'2016-12-09T01:58:22.000Z',
#      u'author': None,
#      u'channel': 0,
#      u'cityid': 0,
#      u'content': u'<div>\n <p>\u5934\u6761\u6700\u8fd1\u662f\u6760\u4e0a\u5f20\u827a\u5174\u4e86\u5417\uff1f\uff01\u5df2\u7ecf\u53d1\u751f\u8fc7\u7684\uff0c\u672a\u6765\u4e0d\u53ef\u80fd\u53d1\u751f\u7684\u2026\u2026\u6211\u4e0d\u660e\u767d\u60a8\u662f\u6709\u591a\u559c\u6b22\u5f20\u827a\u5174\u554a\u3002\u60a8\u8981\u662f\u592a\u95f2\uff0c\u5c31\u53bb\u8865\u8865\u89c9\u5427\uff0c\u60f3\u4e86\u89e3\u5f20\u827a\u5174\u60a8\u5c31\u53bb\u767e\u5ea6\u641c\u4e00\u641c\uff0c\u8fde\u751f\u8fb0\u516b\u5b57\u90fd\u6709\uff0c\u4f55\u5fc5\u63d0\u8fd9\u4e9b\u4e2a\u2026\u2026\u7684\u95ee\u9898\u3002</p>\n <p>\u662f\u5427\uff0c\u5f88\u591a\u8def\u4eba\u90fd\u89c9\u5f97\u6ca1\u6709\u6781\u9650\u6311\u6218\u5c31\u6ca1\u6709\u5f20\u827a\u5174\u7684\u4eca\u5929\uff0c\u662f\uff0c\u6781\u6311\u529f\u4e0d\u53ef\u6ca1\u3002\u5982\u679c\u6ca1\u6709\u6781\u6311\uff0c\u53ef\u80fd\u5f20\u827a\u5174\u5728\u8fd9\u6ce290\u540e\u9c9c\u8089\u4e2d\u8fd8\u5904\u4e8e\u534a\u9690\u5f62\u72b6\u6001\uff0c\u5728\u97e9\u56fd\u4f1a\u88ab\u5632\u7b11\uff0cSM\u5931\u671b\u4e5f\u4e0d\u4f1a\u7ed9\u4ed6\u4eca\u5929\u8fd9\u6837\u7684\u5f85\u9047\uff0c\u4f46\u662f\uff0c\u6211\u8bf4\uff0c\u5f20\u827a\u5174\u7684\u52aa\u529b\u914d\u5f97\u4e0a\u4ed6\u7684\u5e78\u8fd0\u3002</p>\n <p>\u6781\u9650\u5927\u706b\uff0c\u5f20\u827a\u5174\u88ab\u63a8\u4e0a\u4e86\u98ce\u53e3\u6d6a\u5c16\uff0c\u4e00\u4e3e\u6210\u4e3a\u5f53\u7ea2\u5c0f\u9c9c\u8089\uff0c\u63a5\u7740\u5c31\u662f\u4f60\u4eec\u53e3\u4e2d\u7684\u597d\u8fd0\u8fde\u8fde\uff0c\u5982\u679c\u5f20\u827a\u5174\u81a8\u80c0\u4e86\uff0c\u9760\u7740\u5237\u8138\u5356\u840c\u6df7\u5708\u91cc\uff0c\u4f1a\u600e\u6837\uff1f\uff01\u53ef\u80fd\u6709\u4f1a\u6709\u5f88\u591a\u4eba\u8bf4\u53ea\u8981\u4e0d\u662f\u50bb\u5c31\u77e5\u9053\u7ea2\u4e86\u8be5\u600e\u4e48\u505a\u3002\u540c\u662f\u6df7\u5a31\u4e50\u5708\u7684\uff0c\u6709\u50bb\u7684\u5417\uff1f\u53ef\u4e0d\u50bb\u8fd8\u662f\u4f1a\u6709\u4e9b\u827a\u4eba\u505a\u7740\u4e0a\u8ff0\u4e8b\u60c5\uff0c\u5c31\u7b97\u4e0d\u957f\u4e45\uff0c\u6700\u8d77\u7801\u6700\u8fd1\u51e0\u5e74\u8fd8\u662f\u53ef\u4ee5\u7684\uff0c\u6323\u4e9b\u5feb\u94b1\u6295\u4e2a\u8d44\uff0c\u5f00\u4e2a\u5e97\uff0c\u4ee5\u540e\u4e5f\u662f\u53ef\u4ee5\u7684\uff0c\u4e0d\u6101\u5403\u559d\u2026\u2026\u5f20\u827a\u5174\u9009\u7684\u4ec0\u4e48\u8def\uff0c\u4e00\u5e74\u4ee5\u6765\u7684\u52aa\u529b\u548c\u6210\u7ee9\u6709\u76ee\u5171\u7779\u3002\u6781\u6311\u662f\u5f20\u827a\u5174\u7684\u798f\u661f\uff0c\u5230\u6700\u540e\u8fd8\u662f\u9760\u5f20\u827a\u5174\u81ea\u5df1\u3002</p>\n <p>\u5f20\u827a\u5174\u7684\u68a6\u60f3:\u5e26\u9886\u534e\u8bed\u4e50\u575b\u8d70\u5411\u4e16\u754c</p>\n <p>\u77e5\u9053\u81ea\u5df1\u60f3\u8981\u4ec0\u4e48\uff0c\u5e76\u4e3a\u4e4b\u53bb\u52aa\u529b\u3002</p>\n <p>\u672c\u6587\u5938\u8d5e\u90e8\u5206\u7701\u7565\uff0c\u4e0d\u60f3\u5f15\u8def\u4eba\u53cd\u611f\uff0c\u88ab\u8bf4\u5b88\u7740\u90a3\u4fe9\u53e5\u6ca1\u5b8c\u6ca1\u4e86\u4e86\u3002</p>\n <p>\u7efc\u4e0a\u6240\u8ff0\uff0c\u811a\u8e0f\u5b9e\u5730\u8c0b\u53d1\u5c55\uff0c\u52aa\u529b\u52aa\u529b\u518d\u52aa\u529b\u3002</p>\n <p>\u7531\u4e8e\u5f20\u827a\u5174\u8001\u662f\u88ab\u6362\u59d3\uff0c\u6240\u4ee5\u6211\u611f\u5230\u80a9\u4e0a\u4e4b\u91cd\u4efb\uff0c\u4ee5\u540e\u56de\u7b54\u6253\u5168\u540d\u3002</p>\n <p>\u60ef\u4f8b\uff0c\u5949\u5e05\u7167<br><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwkn6b5ffrr2f2jsa_d016075a4f426d09.jpg" alt="\u5982\u679c\u5f20\u827a\u5174\u6ca1\u6709\u52a0\u5165\u6781\u9650\u6311\u6218\uff0c\u4ed6\u73b0\u5728\u662f\u4ec0\u4e48\u60c5\u51b5\uff1f"><br></p>\n</div>',
#      u'digest': None,
#      u'id': 2930962,
#      u'newsfrom': None,
#      u'newsparams': None,
#      u'newstype': 0,
#      u'pic': u'//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkn6b5ffrr2f2jsa_d016075a4f426d09.jpg',
#      u'sortid': 0,
#      u'source': u'\u5934\u6761\u95ee\u7b54',
#      u'state': True,
#      u'tag': u'\u5a31\u4e50',
#      u'tags': [],
#      u'title': u'\u5982\u679c\u5f20\u827a\u5174\u6ca1\u6709\u52a0\u5165\u6781\u9650\u6311\u6218\uff0c\u4ed6\u73b0\u5728\u662f\u4ec0\u4e48\u60c5\u51b5\uff1f',
#      u'type': u't_toutiao',
#      u'url': None},
#     u'_type': u't_toutiao'},
#    {u'_id': u'3139708',
#     u'_index': u'dbwww58com',
#     u'_score': 129.39618,
#     u'_source': {u'@timestamp': u'2016-12-20T07:54:01.032Z',
#      u'@version': u'1',
#      u'addtime': u'2016-12-17T14:07:16.000Z',
#      u'author': None,
#      u'channel': 0,
#      u'cityid': 0,
#      u'content': u'<div>\n <p>\u5728\u8fd9\u91cc\u6211\u8981\u5148\u8bf4\u4e00\u4e0b\uff0c\u6211\u4e5f\u662f\u552f\u996d\u6765\u7740\u554a\uff01\u4f46\u6211\u5148\u8bf4\u660e\uff0c\u6211\u4e0d\u662f\u6bd2\u552f\uff0c\u6211\u4e5f\u6ca1\u6709\u9a82\u8fc7\u5176\u4ed6\u73b0\u961f\u53cb\uff0c\u6211\u53ea\u662f\u4e00\u4e2a\u539f\u672c\u4e0d\u6df7\u97e9\u5708\u7684\u5174\u8ff7\u7f62\u4e86\u3002\u53ea\u8981\u5f20\u827a\u5174\u4e00\u5929\u5728\u56e2\uff0c\u6211\u4e5f\u4e0d\u4f1a\u53bb\u505adiss\u56e2\u7684\u4e8b\u3002\u6211\u4e0d\u5e0c\u671b\u592a\u591a\u4eba\u628a\u5f20\u827a\u5174\u7684\u552f\u996d\u7ed9\u5996\u9b54\u5316\u4e86\u3002</p>\n <p>\u4e2a\u522b\u552f\u996d\u8131\u996d\uff0c\u6211\u60f3\u4e86\u4e00\u4e0b\uff0c\u5927\u6982\u539f\u56e0\u6709\u4e8c\u5427\uff1a\u4e00\u662f\u8fd9\u90e8\u5206\u552f\u996d\u65e0\u611f\u97e9\u56e2\u751a\u81f3\u53cd\u611f\u97e9\u56e2\uff0c\u4f46\u662f\u56e0\u4e3aMAMA\u7684\u53d1\u8a00\uff0c\u6ca1\u6709\u60f3\u8fc7\u5f20\u827a\u5174\u521d\u5fc3\u8fd8\u5728\u56e2\uff0c\u7531\u6b64\u5bf9\u5f20\u827a\u5174\u5931\u671b\uff1b\u4e8c\u53ef\u80fd\u662f\u56e0\u4e3a\u5f20\u827a\u5174\u4eca\u5e74\u6d77\u5916\u6d3b\u52a8\u8fc7\u591a\uff0c\u6ca1\u80fd\u517c\u987e\u56fd\u5185\u5427\u3002\u7b2c\u4e8c\u4e2a\u539f\u56e0\u53ef\u80fd\u6027\u6bd4\u8f83\u5c0f\u5427\uff0c\u5927\u90e8\u5206\u5e94\u8be5\u662f\u4e00\u5427\u3002</p>\n <p>\u4f46\u4e0d\u7ba1\u539f\u56e0\u662f\u4e00\u8fd8\u662f\u4e8c\uff0c\u6211\u90fd\u89c9\u5f97\u633a\u8352\u5510\u7684\u3002\u53ef\u80fd\u6211\u662f\u4eca\u5e74\u624d\u559c\u6b22\u5f20\u827a\u5174\uff0c\u6240\u4ee5\u4e0d\u592a\u80fd\u7406\u89e3\u4ed6\u4eec\u590d\u6742\u7684\u60f3\u6cd5\u5427\u3002\u6211\u4e0d\u660e\u767d\uff0c\u4e3a\u4ec0\u4e48\u603b\u6709\u4e00\u4e9b\u7c89\u4e1d\u559c\u6b22\u628a\u81ea\u5df1\u53d1\u5c55\u6210\u4e8b\u4e1a\u996d\uff0c\u7136\u540e\u4e3a\u5f20\u827a\u5174\u51fa\u8c0b\u732e\u7b56\u3001\u89c4\u5212\u5b8f\u56fe\u3002\u8fd9\u4e00\u70b9\u4e0d\u4ec5\u662f\u5f20\u827a\u5174\u7684\u7c89\u4e1d\uff0c\u56fd\u5185\u4f17\u591a\u82b1\u65e6\u5c0f\u751f\u996d\uff0c\u4e5f\u6709\u8fd9\u79cd\u60c5\u51b5\u54e6\uff01\u4f46\u662f\uff0c\u6211\u4eec\u5ffd\u7565\u4e86\uff0c\u6211\u4eec\u5c31\u662f\u7c89\u4e1d\u800c\u5df2\u554a\uff0c\u6211\u4eec\u53ea\u662f\u8ffd\u8ffd\u661f\uff0c\u996d\u4e2a\u5076\u50cf\u7f62\u4e86\uff0c\u6211\u4eec\u65e2\u6ca1\u6709\u672c\u4e8b\u7ed9\u81ea\u5bb6\u5076\u50cf\u5f00\u5de5\u4f5c\u5ba4\uff0c\u4e5f\u6ca1\u6709\u529e\u6cd5\u7ed9\u4ed6\u627e\u8d44\u6e90\uff0c\u6ca1\u6709\u52bf\u529b\u4e3a\u4ed6\u906e\u98ce\u6321\u96e8\uff0c\u6ca1\u6709\u80fd\u529b\u4e3a\u4ed6\u505a\u5927\u91cf\u5ba3\u4f20\u2026\u2026\u56e0\u4e3a\u6211\u6ca1\u6709\u529e\u6cd5\u505a\u8fd9\u4e9b\u4e8b\uff0c\u6240\u4ee5\u6211\u51b3\u5b9a\u79c9\u627f\u4ee5\u4e0b\u539f\u5219\uff1a\u6709\u65f6\u95f4\u5e2e\u4ed6\u6253\u6253\u699c\u6295\u6295\u7968\uff0c\u6709\u94b1\u5c31\u5e2e\u4ed6\u4e70\u4e70\u4ee3\u8a00\u4e70\u4e70\u4e13\u8f91\uff0c\u89c1\u5230\u4e0d\u597d\u7684\u6076\u610f\u8425\u9500\u5c31\u5e2e\u4ed6\u4e3e\u62a5\uff0c\u591a\u8ddf\u8def\u4eba\u5ba3\u4f20\u4ed6\u3001\u591a\u5938\u4ed6\uff0c\u6162\u6162\u8ddf\u7740\u4ed6\u8d70\u4e0b\u53bb\uff0c\u5176\u4ed6\u4e8b\u60c5\u4e0d\u778e\u63ba\u548c\u3002</p>\n <p>\u6211\u770b\u8fc7\u8131\u996d\u7684\u4eba\uff0c\u6709\u4e9b\u6765\u8def\u4e0d\u660e\uff0c\u6709\u4e00\u4e9b\u4e5f\u786e\u5b9e\u662f\u8d44\u6df1\u8001\u996d\u771f\u7231\u7c89\uff0c\u4e3a\u4ed6\u82b1\u94b1\u82b1\u7cbe\u529b\u7684\u3002\u4f46\u662f\u4ed6\u4eec\u7684\u60f3\u6cd5\u592a\u6df1\u4e86\uff0c\u6211\u603b\u662fget\u4e0d\u5230\u3002\u4f46\u662f\u6240\u8c13\u9053\u4e0d\u540c\u4e0d\u76f8\u4e3a\u8c0b\uff0c\u8ffd\u661f\u4e5f\u662f\u4e00\u6837\u3002\u65e2\u7136\u4f60\u89c9\u5f97\u4f60\u7684\u5076\u50cf\u8ddf\u4f60\u6b65\u4f10\u4e0d\u4e00\u81f4\uff0c\u4e0d\u662f\u4f60\u6240\u60f3\u7684\uff0c\u90a3\u4f60\u5c31\u8131\u996d\u5457\u3002\u8fd9\u662f\u6ca1\u6709\u529e\u6cd5\u7684\u4e8b\u3002\u56e0\u4e3a\u5f20\u827a\u5174\u662f\u4e00\u4e2a25\u5c81\u7684\u62e5\u6709\u72ec\u7acb\u4eba\u683c\u7684\u6210\u5e74\u4 ...
#      u'digest': None,
#      u'id': 3139708,
#      u'newsfrom': None,
#      u'newsparams': None,
#      u'newstype': 0,
#      u'pic': u'//pic1.58cdn.com.cn/p1/small/n_v1bkujjd4uizkvrsx26yga_cdebc1e04c8f0db9.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bkuyfvmuizkvrjfuovta_4efbf870af0a0e2d.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bkuymc4uizkvqd4a7ajq_55b683d383d7d405.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bj3gzseuizkvqemipj4q_e219ad2f289ed6de.jpg',
#      u'sortid': 0,
#      u'source': u'\u5934\u6761\u95ee\u7b54',
#      u'state': True,
#      u'tag': u'\u5a31\u4e50',
#      u'tags': [],
#      u'title': u'\u5982\u4f55\u770b\u5f85\u56e0\u5f20\u827a\u5174MAMA\u53d1\u8a00\u800c\u8131\u996d\u7684\u4e2a\u522b\u552f\u996d\uff1f',
#      u'type': u't_toutiao',
#      u'url': None},
#     u'_type': u't_toutiao'},
#    {u'_id': u'3172345',
#     u'_index': u'dbwww58com',
#     u'_score': 129.36313,
#     u'_source': {u'@timestamp': u'2016-12-20T08:00:05.743Z',
#      u'@version': u'1',
#      u'addtime': u'2016-12-19T03:38:37.000Z',
#      u'author': None,
#      u'channel': 0,
#      u'cityid': 0,
#      u'content': u'<div>\n <p>\u5f20\u827a\u5174\u3002\u6211\u4eec\u4ece\u4e09\u4e2a\u65b9\u9762\u6765\u770b\u5f20\u827a\u5174\u7684\u7efc\u827a\u611f\u3002<br><img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzrz5kzlvrqw73m7q_761c4f57dfed11ac.jpg" alt="\u5185\u5730\u660e\u661f\u4e2d\u6709\u54ea\u4e9b\u5177\u6709\u201c\u7efc\u827a\u611f\u201d\uff1f"><br><br>\u7b2c\u4e00\uff1a\u5e7d\u9ed8\u611f\u3002</p>\n <p>\u5f20\u827a\u5174\u5728\u300a\u6781\u9650\u6311\u6218\u300b\u4e2d\u76f4\u63a5\u5411\u961f\u53cb\u901a\u62a5\u81ea\u5df1\u53db\u53d8\uff0c\u5c06\u94b1\u85cf\u5728\u978b\u5e95\uff0c\u591a\u6b21\u8dd1\u4e22\u6444\u50cf\u5e08\uff0c\u4e0d\u5149\u9017\u7b11\u89c2\u4f17\uff0c\u751a\u81f3\u51e0\u4f4d\u54e5\u54e5\u90fd\u5bf9\u4ed6\u53c8\u54ed\u53c8\u7b11\u3002\u5728\u300a\u6781\u9650\u6311\u6218\u300b\u6536\u5b98\u4e4b\u6218\u4e2d\uff0c\u201c\u5c0f\u732a\u201d\u7f57\u5fd7\u7965\u795e\u6a21\u4eff\u5f20\u827a\u5174\uff0c\u5f20\u827a\u5174\u79ef\u6781\u4e0e\u7f57\u5fd7\u7965\u6253\u914d\u5408\u6218\uff0c\u4ee5\u6b64\u8bde\u751f\u201c\u732a\u7f8a\u53cc\u80de\u80ce\u201d\u8ba9\u8be5\u6bb5\u89c6\u9891\u9887\u5177\u7b11\u70b9\uff0c\u6b64\u540e\u5728\u7f51\u7edc\u4e0a\u75af\u8f6c\u3002</p>\n <p>\u7b2c\u4e8c\uff1a\u8bdd\u9898\u5ea6\u3002</p>\n <p>\u5728\u300a\u6781\u9650\u6311\u6218\u300b\u7b2c\u4e8c\u671f\uff0c\u5f20\u827a\u5174\u4e0a\u5395\u6240\u65f6\u8ba9\u201c\u574f\u53d4\u53d4\u201d\u5b59\u7ea2\u96f7\u6709\u4e86\u53ef\u4e58\u4e4b\u673a\uff0c\u65e0\u60c5\u62ff\u8d70\u81ea\u5df1\u7684\u91d1\u6761\u7bb1\uff0c\u5f20\u827a\u5174\u5728\u5730\u94c1\u4e0a\u4f24\u5fc3\u843d\u6cea\u3001\u4e0d\u80af\u539f\u8c05\u5b59\u7ea2\u96f7\u5f15\u8d77\u4e86\u8282\u76ee\u5f00\u64ad\u7684\u5c0f\u9ad8\u6f6e\u3002\u6709\u6570\u636e\u663e\u793a\u300a\u6781\u9650\u6311\u6218\u300b\u7b2c\u4e8c\u671f\u6536\u89c6\u4ece1.191\u4e0a\u5347\u81f31.729\uff0c\u6536\u89c6\u7387\u4e0a\u6da845%\uff0c\u8bdd\u9898\u5ea6\u589e\u52a070%\uff0c\u201c\u5f20\u827a\u5174\u6781\u9650\u6311\u6218\u201d\u3001\u201c\u5f20\u827a\u5174\u5b59\u7ea2\u96f7\u201d\u7b49\u8bdd\u9898\u4e5f\u7a33\u5c45\u70ed\u641c\u6570\u5929\uff0c\u4ee5\u6b64\u4e0d\u5c11\u4eba\u5c06\u5f20\u827a\u5174\u79f0\u4e3a\u300a\u6781\u9650\u6311\u6218\u300b\u7684\u5c0f\u798f\u661f\u3002<br></p>\n <p>\u7b2c\u4e09\uff1a\u9c9c\u8089\u5c5e\u6027\u5f3a</p>\n <p>\u300a\u6781\u9650\u6311\u6218\u300b\u516d\u5144\u5f1f\u5404\u5177\u7279\u8272\uff0c\u5f20\u827a\u5174\u5f53\u7136\u4ee5\u201c\u5446\u840c\u201d\u8457\u79f0\u3002\u6700\u5e38\u89c1\u7684\u8868\u73b0\u5c31\u662f\u4e0e\u961f\u53cb\u4e0d\u5728\u540c\u4e00\u9891\u9053\uff0c\u5728\u4ee5\u5609\u5bbe\u8eab\u4efd\u53c2\u52a0\u300a\u8dd1\u75372\u300b\u65f6\uff0c\u5f20\u827a\u5174\u672c\u8be5\u5728\u76d1\u63a7\u5ba4\u4e3a\u961f\u53cb\u4f20\u8fbe\u4fe1\u606f\uff0c\u6ca1\u60f3\u5230\u4ed6\u5b8c\u5168\u53d8\u6210\u5750\u5728\u5c4f\u5e55\u524d\u770b\u70ed\u95f9\u7684boy\uff0c\u6700\u7ec8\u672c\u961f\u6495\u540d\u724c\u60e8\u8d25\u3002\u4e0d\u8fc7\uff0c\u5f20\u827a\u5174\u7684\u5446\u840c\u6709\u65f6\u4e5f\u80fd\u4e3a\u4ed6\u5e26\u6765\u597d\u8fd0\uff0c\u5728\u91cd\u5e86\u7ad9\u7535\u68af\u4e0a\u9009\u6700\u957f\u7684\u8304\u5b50\u6311\u6218\u4e2d\uff0c\u5f20\u827a\u5174\u9891\u9891\u5728\u5973\u5b69\u5b50\u4eec\u9762\u524d\u5356\u840c\u800d\u5e05\uff0c\u6700\u7ec8\u5f97\u5230\u6697\u793a\uff0c\u6210\u529f\u5b8c\u6210\u6311\u6218\u3002\u7b2c\u4e09\u671f\u591c\u5e02\u5356\u8d27\u65f6\uff0c\u5f20\u827a\u5174\u773c\u770b\u7740\u672c\u961f\u5904\u4e8e\u52a3\u52bf\uff0c\u72ec\u81ea\u8f6c\u8eab\u5230\u70e4\u8089\u5e97\u7aef\u6765\u4e24\u76d8\u70e4\u8089\uff0c\u5e76\u4e3b\u52a8\u63d0\u51fa\u5582\u7ed9\u7c89\u4e1d\u5403\uff0c\u6210\u529f\u626d\u8f6c\u6218\u5c40\uff0c\u8ba9\u961f\u4f0d\u53cd\u8d25\u4e3a\u80dc\u3002</p>\n <p>\u9664\u4e86\u5446\u840c\uff0c\u5f20\u827a\u5174\u7684\u53e6\u4e00\u7279\u8272\u662f\u6b63\u80fd\u91cf\u5e38\u4f34\u5634\u8fb9\uff0c\u201c\u6211\u89c9\u5f97\u6211\u4eec\u5e94\u5f7c\u6b64\u591a\u4e00\u4e9b\u4fe1\u4efb\u201d\u662f\u4ed6\u53c2\u52a0\u8282\u76ee\u7684\u53e3\u5934\u7 ...
#      u'digest': None,
#      u'id': 3172345,
#      u'newsfrom': None,
#      u'newsparams': None,
#      u'newstype': 0,
#      u'pic': u'//pic1.58cdn.com.cn/p1/small/n_v1bj3gzrz5kzlvrqw73m7q_761c4f57dfed11ac.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkj5kzlvrh4f7bta_d016075a4f426d09.jpg',
#      u'sortid': 0,
#      u'source': u'\u5934\u6761\u95ee\u7b54',
#      u'state': True,
#      u'tag': u'\u5a31\u4e50',
#      u'tags': [],
#      u'title': u'\u5185\u5730\u660e\u661f\u4e2d\u6709\u54ea\u4e9b\u5177\u6709\u201c\u7efc\u827a\u611f\u201d\uff1f',
#      u'type': u't_toutiao',
#      u'url': None},
#     u'_type': u't_toutiao'},
#    {u'_id': u'2887359',
#     u'_index': u'dbwww58com',
#     u'_score': 129.24414,
#     u'_source': {u'@timestamp': u'2016-12-20T07:06:03.544Z',
#      u'@version': u'1',
#      u'addtime': u'2016-12-07T08:24:10.000Z',
#      u'author': None,
#      u'channel': 0,
#      u'cityid': 0,
#      u'content': u'<div>\n <p>\u5f20\u827a\u5174\u5728\u5a31\u4e50\u5708\u91cc\u662f\u51fa\u4e86\u540d\u7684\u8c26\u900a\uff0c\u4e0d\u8bba\u662f\u5728\u6781\u9650\u6311\u6218\u4e2d\u5bf9\u9ec4\u6e24\u3001\u9ec4\u78ca\u7b49\u4e94\u4f4d\u4e00\u53e3\u4e00\u4e2a\u54e5\u54e5\u5916\uff0c\u5728\u5404\u79cd\u6d3b\u52a8\u4e2d\u4e5f\u662f\u4f4e\u8c03\u8c26\u865a\uff0c\u5e38\u5e3890\u5ea6\u97a0\u8eac\uff0c\u5b59\u7ea2\u96f7\u66fe\u8fd9\u6837\u8bc4\u4ef7\uff1a\u4ed6\u592a\u5584\u826f\u4e86\uff0c\u592a\u771f\u8bda\u4e86\u3002\u4e0d\u4f1a\u6700\u8fd1\u5374\u88ab\u97e9\u56fd\u7f51\u53cb\u6012\u9a82\u6ca1\u793c\u8c8c\u3002</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bkujjdzky5dvqy5qum7a_cdebc1e04c8f0db9.jpg" alt="\u5f20\u827a\u5174\u906d\u97e9\u56fd\u7f51\u53cb\u65e0\u7406\u653b\u51fb\uff1a\u6eda\u51fa\u97e9\u56fd \u4e2d\u56fd\u7f51\u53cb\uff1a\u5c31\u8be5\u6709\u6c11\u65cf\u610f\u8bc6"><br></p>\n <p>\u5f20\u827a\u5174\u5230\u5e95\u505a\u4e86\u4ec0\u4e48\uff1f\u5f15\u53d1\u97e9\u56fd\u7f51\u53cb\u7684\u653b\u51fb\u5462\uff0c\u539f\u6765\u662f\u56e0\u4e3a\u5728\u97e9\u56fd\u7684\u67d0\u9881\u5956\u5178\u793c\u4e0a\uff0c\u5bf9\u4e2d\u56fd\u7c89\u4e1d\u8bf4\u4e86\u53e5\uff1a\u8c22\u8c22\u6240\u6709\u7684\u7c89\u4e1d\u670b\u53cb\u4eec\u3002\u4e5f\u5c31\u56e0\u4e3a\u8fd9\u53e5\u8bdd\uff0c\u88ab\u97e9\u56fd\u7f51\u53cb\u6012\u9a82\uff1a\u6eda\u51fa\u97e9\u56fd\uff0c\u6ca1\u793c\u8c8c\u7684\u5bb6\u4f19\uff0c\u63d2\u515c\u8bf4\u8bdd\u3002\u751a\u81f3\u8981\u6c42EXO\u8ba9\u5f20\u827a\u5174\u9000\u961f\u3002</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwwjky5dvqas2nuwa_6666f81f38fd44ce.jpg" alt="\u5f20\u827a\u5174\u906d\u97e9\u56fd\u7f51\u53cb\u65e0\u7406\u653b\u51fb\uff1a\u6eda\u51fa\u97e9\u56fd \u4e2d\u56fd\u7f51\u53cb\uff1a\u5c31\u8be5\u6709\u6c11\u65cf\u610f\u8bc6"><br></p>\n <p>\u5176\u5b9e\u5728\u6574\u4e2a\u9881\u5956\u5178\u793c\u4e0a\uff0c\u5f20\u827a\u5174\u65e0\u6570\u6b2190\u5ea6\u97a0\u8eac\uff0c\u800c\u4ec5\u4ec5\u56e0\u4e3a\u8bf4\u4e2d\u6587\u5c31\u88ab\u6012\u9a82\uff0c\u5b9e\u5728\u662f\u8bf4\u4e0d\u8fc7\u53bb\u3002<br></p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwxrky5dvquwkha7q_c5e82e3eff7fcb9a.jpg" alt="\u5f20\u827a\u5174\u906d\u97e9\u56fd\u7f51\u53cb\u65e0\u7406\u653b\u51fb\uff1a\u6eda\u51fa\u97e9\u56fd \u4e2d\u56fd\u7f51\u53cb\uff1a\u5c31\u8be5\u6709\u6c11\u65cf\u610f\u8bc6"><br></p>\n <p>\u5bf9\u4e8e\u8fd9\u6837\u7684\u4e3e\u52a8\uff0c\u4e2d\u56fd\u7f51\u53cb\u4eec\u7eb7\u7eb7\u53d1\u8868\u89c2\u70b9\uff0c\u8868\u793a\u81ea\u4ece\u9650\u97e9\u4ee4\u540e\uff0c\u5f20\u827a\u5174\u5c31\u88ab\u5404\u79cd\u9ed1\u3002\u8fd8\u6709\u7f51\u53cb\u8c03\u4f83\uff1a\u827a\u5174\u5176\u5b9e\u65e9\u5c31\u8be5\u56de\u56fd\u4e86\uff0c\u6ca1\u6709EXO\u7684\u4f60\u4e5f\u4e00\u6837\u80fd\u6df7\u51fa\u5929\u5730\u3002\u73b0\u5728\u7684\u5f20\u827a\u5174\u5df2\u7ecf\u4e0d\u662f\u4e4b\u524d\u53ea\u4f1a\u5531\u6b4c\u8df3\u821e\u7684\u5f20\u827a\u5174\u4e86\u3002\u5728\u6781\u9650\u7537\u4eba\u5e2e\u5144\u5f1f\u7684\u8c03\u6559\u4e0b\uff0c\u5c24\u5176\u662f\u4e0e\u5b59\u7ea2\u96f7\u5408\u4f5c\u8fc7\u540e\uff0c\u6f14\u6280\u597d\u5230\u4e0d\u884c\u3002<br><br><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwxrky5dvrohelfkq_c5e82e3eff7fcb9a.jpg" alt="\u5f20\u827a\u5174\u906d\u97e9\u56fd\u7f51\u53cb\u65e0\u7406\u653b\u51fb\uff1a\u6eda\u51fa\u97e9\u56fd \u4e2d\u56fd\u7f51\u53cb\uff1a\u5c31\u8be5\u6709\u6c11\u65cf\u610f\u8bc6"><br><br></p>\n <p>\u4e0d\u8fc7\u4e5f\u6709\u7f51\u53cb\u8868\u793a\uff1a\u63d2\u515c\u7684\u786e\u662f\u6709\u70b9\u4e0d\u59a5\uff0c\u4e0d\u8fc7\u56e0\u4e3a\u4e00\u70b9\u5426\u8ba4\u5f20\u827a\u5174\u768490\u5ea6\u97a0\u8eac\uff0c\u672a\u514d\u6709\u70b9\u8fc7\u4e86\u3002\u5176\u5b9e\u5728\u5c0f\u7f16\u770b\u6765\uff0c\u4e2d\u56fd\u4eba\u7684\u786e\u9700\u8981\u4e00\u4e9b\u6c11\u65cf\u610f\u8bc6\uff0c\u8fd9\u4e00\u70b9\u5f20\u827a\u5174\u505a\u7684\u975e\u5e38\u597d\u3002\u4e4b\u524d\u5f20\u827a\u5174\u66fe\u7528\u4e2d\u56fd\u5730\u56fe\u505a\u8fc7\u5fae\u535a\u5934\u50cf\uff0c\u4e5f\u56e0\u6b64\uff0c\u5927\u4f17\u ...
#      u'digest': None,
#      u'id': 2887359,
#      u'newsfrom': None,
#      u'newsparams': None,
#      u'newstype': 0,
#      u'pic': u'//pic1.58cdn.com.cn/p1/small/n_v1bkujjdzky5dvqy5qum7a_cdebc1e04c8f0db9.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwwjky5dvqas2nuwa_6666f81f38fd44ce.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwxrky5dvquwkha7q_c5e82e3eff7fcb9a.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwxrky5dvrohelfkq_c5e82e3eff7fcb9a.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bkuymczky5dvq2cnbeja_55b683d383d7d405.jpg',
#      u'sortid': 0,
#      u'source': u'\u563f\u5a31\u4e50',
#      u'state': True,
#      u'tag': u'\u5a31\u4e50',
#      u'tags': [],
#      u'title': u'\u5f20\u827a\u5174\u906d\u97e9\u56fd\u7f51\u53cb\u65e0\u7406\u653b\u51fb\uff1a\u6eda\u51fa\u97e9\u56fd \u4e2d\u56fd\u7f51\u53cb\uff1a\u5c31\u8be5\u6709\u6c11\u65cf\u610f\u8bc6',
#      u'type': u't_toutiao',
#      u'url': None},
#     u'_type': u't_toutiao'},
#    {u'_id': u'2546979',
#     u'_index': u'dbwww58com',
#     u'_score': 129.04146,
#     u'_source': {u'@timestamp': u'2016-12-20T06:07:03.686Z',
#      u'@version': u'1',
#      u'addtime': u'2016-11-23T20:52:57.000Z',
#      u'author': None,
#      u'channel': 0,
#      u'cityid': 0,
#      u'content': u'<p>\u5f20\u827a\u5174\u5728\u4e2d\u56fd\u4ee5\u7ae5\u661f\u51fa\u9053\uff0c\u540e\u6765\u53bb\u97e9\u56fd\u53d1\u5c55\u3002\u4e0d\u7ba1\u8eab\u5728\u54ea\u91cc\uff0c\u5f20\u827a\u5174\u4e00\u76f4\u90fd\u662f\u4e00\u4e2a\u52aa\u529b\u3001\u6709\u793c\u8c8c\u3001\u6709\u6559\u517b\u7684\u660e\u661f\u3002\u5411\u7c89\u4e1d\u4eec\u97a0\u8eac\uff0c\u4ee5\u81ea\u5df1\u6700\u5927\u7684\u8bda\u610f\u4e0e\u611f\u8c22\u3002</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bkuyfvnjae3fqolahq2a_4efbf870af0a0e2d.jpg">\n<p></p>\n<p>\u81ea\u5df1\u6ca1\u529e\u6cd5\u4e3a\u7c89\u4e1d\u4eec\u4e00\u4e00\u4eb2\u624b\u505a\u4ec0\u4e48\u4e8b\u60c5\uff0c\u4f46\u5979\u4eec\u5374\u7231\u4ed6\u5982\u6b64\u3002\u5f20\u827a\u5174\u662f\u611f\u8c22\u7684\uff01</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bkuymc5jae3fqort6bpq_55b683d383d7d405.jpg">\n<p></p>\n<p>\u5f20\u827a\u5174\u6709\u5f88\u4e25\u91cd\u7684\u8170\u4f24\uff0c\u4f46\u6bcf\u4e00\u4e2a\u97a0\u8eac\u90fd\u662f\u90a3\u4e48\u8ba4\u771f\u3002360\u5ea6\u5168\u573a\u97a0\u8eac\uff0c\u6bcf\u4e2a\u90fd\u662f\u6807\u51c6\u768490\u5ea6\u3002</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bkuymc5jae3frt3fjiqa_55b683d383d7d405.jpg">\n<p></p>\n<div id="hidtag"></div>\n<p>\u611f\u6fc0\u7c89\u4e1d\u53bb\u542c\u4ed6\u8bf4\u5f97\u8bdd\u3001\u542c\u4ed6\u5531\u5f97\u6b4c\u3002\u5f20\u827a\u5174\u7528\u97a0\u8eac\u6765\u611f\u8c22\u5979\u4eec\u3002\u6c38\u8fdc\u6bd4\u522b\u4eba\u97a0\u8eac\u8981\u4f4e\uff0c\u8c26\u865a\u6709\u793c\u8c8c\u7684\u5f20\u827a\u5174\uff01</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwxviae3frz62546q_c5e82e3eff7fcb9a.jpg">\n<p></p>\n<p>\u660e\u661f\u53ea\u6709\u628a\u81ea\u5df1\u7684\u59ff\u6001\u653e\u4f4e\uff0c\u548c\u7c89\u4e1d\u505a\u670b\u53cb\uff0c\u624d\u80fd\u5f97\u5230\u6700\u771f\u8bda\u7684\u652f\u6301\u4e0e\u7231\u62a4\u3002</p>\n<p>\u5f20\u827a\u5174\u81ea\u4ece\u53c2\u52a0\u4e86\u300a\u6781\u9650\u6311\u6218\u300b\uff0c\u5728\u56fd\u5185\u53ef\u4ee5\u8bf4\u5708\u7c89\u65e0\u6570\uff0c\u987a\u5229\u7684\u4ece\u97e9\u56fd\u8f6c\u5411\u4e86\u56fd\u5185\uff0c\u73b0\u5728\u4e3b\u8981\u53d1\u5c55\u65b9\u5411\u5c31\u662f\u56fd\u5185\uff0c\u987a\u4fbf\u517c\u987e\u7740\u97e9\u56fd\u7684\u53d1\u5c55\uff0c\u6bd5\u7adf\u5f20\u827a\u5174\u73b0\u5728\u662f\u97e9\u56fdEXO\u56e2\u961f\u7684\u6210\u5458\u3002</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwxviae3fq4mpeuuq_c5e82e3eff7fcb9a.jpg">\n<p></p>\n<p>\u4f46\u662f\u968f\u7740\u5e7f\u7535\u603b\u5c40\u7684\u9650\u97e9\u4ee4\u7684\u5b9e\u65bd\uff0c\u97e9\u56fd\u827a\u4eba\u90fd\u5df2\u7ecf\u79bb\u5f00\u5927\u9646\u6253\u5305\u56de\u56fd\u4e86\uff0c\u6240\u4ee5\u97e9\u56fd\u7f51\u53cb\u5fc3\u91cc\u4e5f\u618b\u7740\u4e00\u53e3\u6c14\uff0c\u73b0\u5728\u5f20\u827a\u5174\u53bb\u97e9\u56fd\u53c2\u52a0\u6d3b\u52a8\uff0c\u97e9\u56fd\u7f51\u53cb\u5f00\u59cb\u5904\u5904\u4e3a\u96be\u5f20\u827a\u5174\u4e86\u3002</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bkuyfvnjae3fq534kmnq_4efbf870af0a0e2d.jpg">\n<p></p>\n<p>\u5f20\u827a\u5174\u5728\u97e9\u56fd\u51fa\u5e2d\u6d3b\u52a8\u7684\u65f6\u5019\uff0c\u56e0\u4e3a\u628a\u624b\u63d2\u5728\u515c\u91cc\uff0c\u97e9\u56fd\u7f51\u53cb\u76f4\u63a5\u5927\u9a82\u5f20\u827a\u5174\u50b2\u6162\u65e0\u793c\u5927\u724c\u3002\u5927\u5bb6\u90fd\u77e5\u9053\u5f20\u827a\u5174\u88ab\u79f0\u5c0f\u7ef5\u7f8a\uff0c\u4e00\u76f4\u90fd\u662f\u7279\u522b\u793c\u8c8c\u7684\u4eba\uff0c\u505a\u4e8b\u60c5\u4e5f\u662f\u7279\u522b\u6696\u5fc3\u3002</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzsfjae3fqxce2ywq_e219ad2f289ed6de.jpg">\n<p></p>\n<p>\u53cc\u624b\u63d2\u515c\u5176\u5b9e\u662f\u5f20\u827a\u5174\u7684\u4e60\u60ef\u800c\u5df2\uff0c\u5e76\u4e0d\u662f\u4ec0\u4e48\u50b2\u6162\u800d\u5927\u724c\u3002\u6211\u95fa\u871c\u53ef\u662f\u8d85\u7ea7\u559c\u6b22\u5f20\u827a\u5174\u554a\u524d\u4e9b\u65e5\u5b50\u5c0f\u7f16\u53bb\u95fa\u871c\u5bb6\u8ba8\u8bba\u5c0f\u7ef5\u7f8a\uff0c\u5979\u5c45\u7136\u5728\u5b66\u71ac\u7ca5\uff0c\u8bf4\u53ef\u4ee5\u7626\u8eab\uff0c\u8fd9\u4e0d\u626f\u6de1\u5417\uff0c\u7ca5\u8f ...
#      u'digest': None,
#      u'id': 2546979,
#      u'newsfrom': None,
#      u'newsparams': None,
#      u'newstype': 0,
#      u'pic': u'//pic1.58cdn.com.cn/p1/small/n_v1bkuyfvnjae3fqolahq2a_4efbf870af0a0e2d.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bkuymc5jae3fqort6bpq_55b683d383d7d405.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bkuymc5jae3frt3fjiqa_55b683d383d7d405.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwxviae3frz62546q_c5e82e3eff7fcb9a.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwxviae3fq4mpeuuq_c5e82e3eff7fcb9a.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bkuyfvnjae3fq534kmnq_4efbf870af0a0e2d.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bj3gzsfjae3fqxce2ywq_e219ad2f289ed6de.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bkujjd5jae3frhbkrabq_cdebc1e04c8f0db9.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bkujjd5jae3fre6nuavq_cdebc1e04c8f0db9.jpg',
#      u'sortid': 0,
#      u'source': u'\u5a31\u4e50\u60c5\u62a5',
#      u'state': True,
#      u'tag': u'\u5a31\u4e50 \u5f20\u827a\u5174 \u660e\u661f',
#      u'tags': [],
#      u'title': u'\u5f20\u827a\u5174\u7684\u8c26\u900a\u5374\u88ab\u97e9\u56fd\u68d2\u5b50\u9a82\u60e8\u4e86, \u5c0f\u7ef5\u7f8a\u59d4\u5c48\u54ed',
#      u'type': u't_toutiao',
#      u'url': None},
#     u'_type': u't_toutiao'},
#    {u'_id': u'2768007',
#     u'_index': u'dbwww58com',
#     u'_score': 128.63031,
#     u'_source': {u'@timestamp': u'2016-12-20T06:45:04.143Z',
#      u'@version': u'1',
#      u'addtime': u'2016-12-02T12:53:45.000Z',
#      u'author': None,
#      u'channel': 0,
#      u'cityid': 0,
#      u'content': u'<p>\u5f20\u827a\u5174\u7684\u961f\u4f0dEXO\u53c2\u52a0\u97e9\u56fd\u9881\u5956\u793c\uff0c\u5168\u7a0b\u53cc\u624b\u63d2\u888b\u8bf4\u4e2d\u6587\uff0c\u5f15\u8d77\u5f88\u591a\u97e9\u56fd\u7f51\u53cb\u751a\u81f3\u7c89\u4e1d\u7684\u6012\u65a5\uff1a\u8bf4\u529d\u5176\u9000\u51fa\u961f\u4f0d\uff0c\u8bf4\u4e0d\u8981\u51fa\u73b0\u5728\u97e9\u56fd\uff0c\u8bf4\u827a\u5174\u4e0d\u61c2\u793c\u8282\u3002</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwkgznzavrjqhgbpa_d016075a4f426d09.jpg">\n<p></p>\n<p>\u4e2d\u56fd\u7684\u9650\u97e9\u4ee4\u5b9e\u65bd\u4ee5\u540e\uff0c\u97e9\u56fd\u827a\u4eba\u57fa\u672c\u5728\u4e2d\u56fd\u6d88\u5931\u4e86\uff0c\u8fd9\u4e5f\u5f15\u8d77\u4e86\u97e9\u56fd\u7f51\u53cb\u7684\u62b5\u5236\uff0c\u4ece\u800c\u628a\u6028\u6c14\u4e5f\u53d1\u6cc4\u5230\u4e86\u5f20\u827a\u5174\u8eab\u4e0a\u3002</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bkuyfvoznzavq7m5dnjq_4efbf870af0a0e2d.jpg">\n<p></p>\n<p>\u9762\u5bf9\u56fd\u5916\u7c89\u4e1d\u7684\u8d28\u7591\uff0c\u5f20\u827a\u5174\u6beb\u65e0\u6240\u60e7\u7684\u56de\u5e94\uff1a\u56fd\u5bb6\u9762\u524d\u65e0\u7c89\u4e1d\uff01\u597d\u4e00\u4e2a\u56fd\u5bb6\u9762\u524d\u65e0\u7c89\u4e1d\uff0c\u5f20\u827a\u5174\u4f9d\u65e7\u662f\u90a3\u4e2a\u5f20\u827a\u5174\uff0c\u4eba\u54c1\u597d\uff0c\u4e09\u89c2\u6b63\uff0c\u4ed6\u4f9d\u65e7\u662f\u90a3\u4e2a\u5c5e\u4e8e\u4e2d\u56fd\u7684\u5f20\u827a\u5174\uff0c\u62e5\u6709\u4e2d\u56fd\u5fc3\u7684\u5f20\u827a\u5174\uff01</p>\n<p>\u5f20\u827a\u5174\u8868\u793a\u5728\u97e9\u56fd\u7684\u9881\u5956\u5178\u793c\u4e0a\u5168\u7a0b\u4f7f\u7528\u4e2d\u6587\uff0c\u8868\u73b0\u4e86\u4ed6\u6d53\u70c8\u7684\u7231\u56fd\u4e4b\u5fc3~\u56e0\u4e3a\u54b1\u4eec\u662f\u4e2d\u56fd\u4eba\uff0c\u5bf9\u5427\uff0c\u4e3a\u5565\u4e0d\u8bf4\u4e2d\u6587</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzsgznzavrzuw4vhq_e219ad2f289ed6de.jpg">\n<p></p>\n<div id="hidtag"></div>\n<p>\u4e0d\u8fc7\u8fd8\u662f\u771f\u5fc3\u75bc\u5f20\u827a\u5174\uff0c\u56de\u56fd\u5427\uff0c\u56fd\u5185\u7684\u7c89\u4e1d\u4e0d\u4f1a\u4e8f\u5f85\u4f60\u7684\u3002</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bkuymc6znzavrvyfkiuq_55b683d383d7d405.jpg">\n<p></p>',
#      u'digest': None,
#      u'id': 2768007,
#      u'newsfrom': None,
#      u'newsparams': None,
#      u'newstype': 0,
#      u'pic': u'//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkgznzavrjqhgbpa_d016075a4f426d09.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bkuyfvoznzavq7m5dnjq_4efbf870af0a0e2d.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bj3gzsgznzavrzuw4vhq_e219ad2f289ed6de.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bkuymc6znzavrvyfkiuq_55b683d383d7d405.jpg',
#      u'sortid': 0,
#      u'source': u'\u4e09\u4fa0TV',
#      u'state': True,
#      u'tag': u'\u5a31\u4e50 \u5f20\u827a\u5174 \u660e\u661f',
#      u'tags': [],
#      u'title': u'\u5f20\u827a\u5174\u5728\u97e9\u56fd\u9881\u5956\u793c\u8bf4\u4e2d\u6587\u88ab\u9a82, \u5f20\u827a\u5174\u7684\u56de\u5e94\u503c\u5f97\u70b9\u8d5e',
#      u'type': u't_toutiao',
#      u'url': None},
#     u'_type': u't_toutiao'},
#    {u'_id': u'2971000',
#     u'_index': u'dbwww58com',
#     u'_score': 128.61858,
#     u'_source': {u'@timestamp': u'2016-12-20T07:20:07.296Z',
#      u'@version': u'1',
#      u'addtime': u'2016-12-10T18:44:30.000Z',
#      u'author': None,
#      u'channel': 0,
#      u'cityid': 0,
#      u'content': u'<div>\n <p><strong>\u672c\u6587\u7531\u2018\u2019\u52b2\u7206\u5a31\u4e50\u4e8b\u201d\u539f\u521b\uff0c\u8f6c\u8f7d\u8bf7\u6ce8\u660e\u6765\u6e90~</strong></p>\n <p>\u4f60\u4ee5\u4e3a\u5355\u7eaf\u53ef\u7231\u7684\u5c0f\u7ef5\u7f8a\u5f20\u827a\u5174\u662f\u8fd9\u79cd\u8001\u5b9e\u7684\u62b1\u7740\u5409\u4ed6\uff1f</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bkuyfvimjvgfqwbt4yqq_4efbf870af0a0e2d.jpg" alt="\u5730\u677f\u821e\u771f\u6c61\u8fa3\u773c\u775b\uff01\u5f20\u827a\u5174\u7adf\u8fd9\u4e48\u201c\u4e0d\u5bb3\u81ca\u201d"><br></p>\n <p>\u6216\u662f\u8fd9\u6837\u6df1\u60c5\u5730\u5f39\u7740\u94a2\u7434\u7684\u5c11\u5e74\uff1f</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bkujjdymjvgfrmh2qj3q_cdebc1e04c8f0db9.jpg" alt="\u5730\u677f\u821e\u771f\u6c61\u8fa3\u773c\u775b\uff01\u5f20\u827a\u5174\u7adf\u8fd9\u4e48\u201c\u4e0d\u5bb3\u81ca\u201d"><br></p>\n <p>\u5176\u5b9e\uff0c\u5e76\u4e0d\u662f\uff0c\u63a5\u4e0b\u6765\u624d\u662f\u5c0f\u7ef5\u7f8a\u7684\u6b63\u786e\u6253\u5f00\u65b9\u5f0f\uff1a</p>\n <p><strong>\u7ecf\u8fc7\u201c\u6781\u9650\u7537\u4eba\u5e2e\u201d\u957f\u65f6\u95f4\u7684\u8c03\u6559\uff0c\u5f20\u827a\u5174\u65e9\u5df2\u4e0d\u662f\u5f53\u521d\u7684\u90a3\u4e2a\u5c0f\u7ef5\u7f8a\u4e86</strong></p>\n <p><strong><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwwimjvgfr3wvuira_6666f81f38fd44ce.jpg" alt="\u5730\u677f\u821e\u771f\u6c61\u8fa3\u773c\u775b\uff01\u5f20\u827a\u5174\u7adf\u8fd9\u4e48\u201c\u4e0d\u5bb3\u81ca\u201d"><br></strong></p>\n <p><strong>\u8fd1\u65e5\uff0c\u5f20\u827a\u5174\u5230\u300a\u5929\u5929\u5411\u4e0a\u300b\uff0c\u8fd8\u5728\u8282\u76ee\u4e0a\u6f14\u4e86\u4e00\u6bb5\u8ba9\u4eba\u6c61\u773c\u775b\u7684\u5730\u677f\u821e</strong></p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwkiojvgfqnuhornq_d016075a4f426d09.gif" alt="\u5730\u677f\u821e\u771f\u6c61\u8fa3\u773c\u775b\uff01\u5f20\u827a\u5174\u7adf\u8fd9\u4e48\u201c\u4e0d\u5bb3\u81ca\u201d"><br></p>\n <p>\u5567\u5567\u5567\uff0c\u8fd9\u753b\u9762\u6709\u70b9\u6c61\u554a...\u77a7\u8fd9\u53f0\u4e0b\u7684\u4e00\u7fa4\u59b9\u5b50\u90fd\u6fc0\u52a8\u7684\u4e0d\u884c\u4e86\u3002\u6cb8\u817e\u7684\u8ff7\u59b9\u4eec\uff0c\u6de1\u5b9a\u6de1\u5b9a</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzrymjvgfqsrv2iqa_761c4f57dfed11ac.gif" alt="\u5730\u677f\u821e\u771f\u6c61\u8fa3\u773c\u775b\uff01\u5f20\u827a\u5174\u7adf\u8fd9\u4e48\u201c\u4e0d\u5bb3\u81ca\u201d"><br></p>\n <p>\u5176\u5b9e\u5427\uff0c\u5f20\u827a\u5174\u8df3\u8fd9\u7f9e\u6da9\u7684\u5730\u677f\u821e\uff0c\u4e0d\u662f\u7b2c\u4e00\u6b21\u5462\uff0c\u8fd8\u6709\u66f4\u6c61\uff0c\u66f4\u6027\u611f\u7684\uff01</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwtimjvgfqo6ugrma_6c7ea76f39c78102.gif" alt="\u5730\u677f\u821e\u771f\u6c61\u8fa3\u773c\u775b\uff01\u5f20\u827a\u5174\u7adf\u8fd9\u4e48\u201c\u4e0d\u5bb3\u81ca\u201d"><br></p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwkamjvgfr7odzzta_d016075a4f426d09.gif" alt="\u5730\u677f\u821e\u771f\u6c61\u8fa3\u773c\u775b\uff01\u5f20\u827a\u5174\u7adf\u8fd9\u4e48\u201c\u4e0d\u5bb3\u81ca\u201d"><br></p>\n <p>\u5c0f\u7ef5\u7f8a\u8fd9\u8170\u529b\u771f\u662f\u597d\u5230\u4e0d\u884c\u554a\uff0c\u8170\u677f\u597d\uff0c\u67d4\u8f6f\u5440\uff01</p>\n <p>\u4e0d\u8fc7\u5f88\u591a\u4eba\u8bf4\u5730\u677f\u821e\u7b97\u4ec0\u4e48\uff0c\u4f60\u770b\u8fd9\u4e2a\u62d0\u6756\u821e</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwkimjvgfq4xlryzq_d016075a4f426d09.gif" alt="\u5730\u677f\u821e\u771f\u6c61\u8fa3\u773c\u775b\uff01\u5f20\u827a\u5174\u7adf\u8fd9\u4e48\u201c\u4e0d\u5bb3\u81ca\u201d"><br></p>\n <p>\u4e0d\u8981\u4ee5\u4e3a\u8fd9\u6837\u5c31\u6ca1\u4e86\u3002<strong>\u5f20\u827a\u5174\u8fd8\u6709\u6e7f\u8eab\u821e\u554a\u3001\u8131\u8863\u821e\uff0c\u8499\u773c\u821e\uff01\u5c0f\u7ef5\u7f8a\u8fd9\u5b8c\u5168\u8d70\u7684\u5c31\u662f\u7981\u6b32\u7cfb\u8def\u7ebf\uff1f\u5c0f\u7ef5\u7f8a\u662f\u4e0d\u662f\u8be5\u6539\u540d\u4e86\u5462\uff1f\u54c8\u54c8\u54c8</strong></p>\n <p><strong><img src="//pic1.58cdn.com.cn/p1/big/ ...
#      u'digest': None,
#      u'id': 2971000,
#      u'newsfrom': None,
#      u'newsparams': None,
#      u'newstype': 0,
#      u'pic': u'//pic1.58cdn.com.cn/p1/small/n_v1bkuyfvimjvgfqwbt4yqq_4efbf870af0a0e2d.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bkujjdymjvgfrmh2qj3q_cdebc1e04c8f0db9.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwwimjvgfr3wvuira_6666f81f38fd44ce.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkiojvgfqnuhornq_d016075a4f426d09.gif|//pic1.58cdn.com.cn/p1/small/n_v1bj3gzrymjvgfqsrv2iqa_761c4f57dfed11ac.gif|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwtimjvgfqo6ugrma_6c7ea76f39c78102.gif|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkamjvgfr7odzzta_d016075a4f426d09.gif|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkimjvgfq4xlryzq_d016075a4f426d09.gif|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkamjvgfqsfgpmhq_d016075a4f426d09.jpg',
#      u'sortid': 0,
#      u'source': u'\u52b2\u7206\u5a31\u4e50\u4e8b',
#      u'state': True,
#      u'tag': u'\u5a31\u4e50',
#      u'tags': [],
#      u'title': u'\u5730\u677f\u821e\u771f\u6c61\u8fa3\u773c\u775b\uff01\u5f20\u827a\u5174\u7adf\u8fd9\u4e48\u201c\u4e0d\u5bb3\u81ca\u201d',
#      u'type': u't_toutiao',
#      u'url': None},
#     u'_type': u't_toutiao'},
#    {u'_id': u'2683262',
#     u'_index': u'dbwww58com',
#     u'_score': 128.59312,
#     u'_source': {u'@timestamp': u'2016-12-20T06:30:07.565Z',
#      u'@version': u'1',
#      u'addtime': u'2016-11-29T11:02:24.000Z',
#      u'author': None,
#      u'channel': 0,
#      u'cityid': 0,
#      u'content': u'<div>\n <p>\u5f20\u827a\u5174\u7684\u961f\u4f0dEXO\u53c2\u52a0\u97e9\u56fd\u9881\u5956\u793c\uff0c\u5168\u7a0b\u53cc\u624b\u63d2\u888b\u8bf4\u4e2d\u6587\uff0c\u5f15\u8d77\u5f88\u591a\u97e9\u56fd\u7f51\u53cb\u751a\u81f3\u7c89\u4e1d\u7684\u6012\u65a5\uff1a\u8bf4\u529d\u5176\u9000\u51fa\u961f\u4f0d\uff0c\u8bf4\u4e0d\u8981\u51fa\u73b0\u5728\u97e9\u56fd\uff0c\u8bf4\u827a\u5174\u4e0d\u61c2\u793c\u8282\u3002</p>\n <p>\u6b64\u524d\u6709\u6d88\u606f\u79f0\u97e9\u56fd\u7f51\u53cb\u56e0\u4e3a\u9650\u97e9\u4ee4\u4e5f\u5f00\u59cb\u9488\u5bf9\u4e2d\u56fd\u660e\u661f\uff0c\u5bfc\u81f4\u4e86\u5f20\u827a\u5174\u5728\u9881\u5956\u5178\u793c\u4e0a\u624b\u63d2\u515c\u3001\u5168\u7a0b\u8bb2\u4e2d\u6587\u7684\u5c0f\u7ec6\u8282\u5c31\u6210\u4e86\u4f17\u77e2\u4e4b\u7684\uff01</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzsb7ma6vryfuw4uq_e219ad2f289ed6de.jpg" alt="\u5f20\u827a\u5174\u7528\u884c\u52a8\u545b\u97e9\u56fd\u7f51\u53cb\uff1a\u8bf4\u4e2d\u6587\uff0c\u56e0\u4e3a\u6211\u662f\u4e2d\u56fd\u4eba\uff01"><br></p>\n <p>\u4f46\u662f\uff0c\u8bf7\u4f60\u4eec\u4ed4\u7ec6\u7684\u770b\u770b\u6e05\u695a\uff0c\u5f20\u827a\u5174\u6bcf\u6b21\u7684\u8868\u6f14\u90fd\u662f\u8ba4\u771f\u5230\u4e0d\u884c\uff0c\u4e3a\u4e86\u8eab\u6750\u4e0a\u955c\u751a\u81f3\u4e3a\u4e86\u7c89\u4e1d\u4e3a\u4e86\u6d3b\u52a8\u81ea\u5df1\u90fd\u7d2f\u6655\u4e86\u51e0\u6b21\u4e86\uff0c\u5927\u5bb6\u90fd\u77e5\u9053\u3002\u8fd8\u6709\u5c31\u662f\u6700\u51fa\u540d\u7684\u827a\u5174\u97a0\u8eac\uff0c\u56e0\u4e3a\u8170\u4f24\uff0c\u81ea\u5df1\u5f2f\u8170\u90fd\u56f0\u96be\u7684\u5f20\u827a\u5174\u6bcf\u6b21\u7ed9\u7c89\u4e1d\u97a0\u8eac90\u5ea6\uff0c\u8fd8\u65f6\u95f4\u90a3\u4e48\u4e45\uff0c\u8fd8\u8f6c\u7740\u5708\u7684\u97a0\u8eac\uff0c</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzsb7ma6vrypmcrmq_e219ad2f289ed6de.gif" alt="\u5f20\u827a\u5174\u7528\u884c\u52a8\u545b\u97e9\u56fd\u7f51\u53cb\uff1a\u8bf4\u4e2d\u6587\uff0c\u56e0\u4e3a\u6211\u662f\u4e2d\u56fd\u4eba\uff01"><br></p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzrz7ma6vqfknaa5a_761c4f57dfed11ac.jpg" alt="\u5f20\u827a\u5174\u7528\u884c\u52a8\u545b\u97e9\u56fd\u7f51\u53cb\uff1a\u8bf4\u4e2d\u6587\uff0c\u56e0\u4e3a\u6211\u662f\u4e2d\u56fd\u4eba\uff01"><br></p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwwj7ma6vrizr5niq_6666f81f38fd44ce.jpg" alt="\u5f20\u827a\u5174\u7528\u884c\u52a8\u545b\u97e9\u56fd\u7f51\u53cb\uff1a\u8bf4\u4e2d\u6587\uff0c\u56e0\u4e3a\u6211\u662f\u4e2d\u56fd\u4eba\uff01"><br></p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwkb7ma6vqqkjpzta_d016075a4f426d09.jpg" alt="\u5f20\u827a\u5174\u7528\u884c\u52a8\u545b\u97e9\u56fd\u7f51\u53cb\uff1a\u8bf4\u4e2d\u6587\uff0c\u56e0\u4e3a\u6211\u662f\u4e2d\u56fd\u4eba\uff01"><br></p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzsb7ma6vqxmwqj3q_e219ad2f289ed6de.jpg" alt="\u5f20\u827a\u5174\u7528\u884c\u52a8\u545b\u97e9\u56fd\u7f51\u53cb\uff1a\u8bf4\u4e2d\u6587\uff0c\u56e0\u4e3a\u6211\u662f\u4e2d\u56fd\u4eba\uff01"><br></p>\n <p>\u5f20\u827a\u5174\u8868\u793a\u5728\u97e9\u56fd\u7684\u9881\u5956\u5178\u793c\u4e0a\u5168\u7a0b\u4f7f\u7528\u4e2d\u6587\uff0c\u8868\u73b0\u4e86\u4ed6\u6d53\u70c8\u7684\u7231\u56fd\u4e4b\u5fc3~\u56e0\u4e3a\u54b1\u4eec\u662f\u4e2d\u56fd\u4eba\uff0c\u5bf9\u5427\uff0c\u4e3a\u5565\u4e0d\u8bf4\u4e2d\u6587</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwkj7ma6vrdhvcm5a_d016075a4f426d09.jpg" alt="\u5f20\u827a\u5174\u7528\u884c\u52a8\u545b\u97e9\u56fd\u7f51\u53cb\uff1a\u8bf4\u4e2d\u6587\uff0c\u56e0\u4e3a\u6211\u662f\u4e2d\u56fd\u4eba\uff01"><br></p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzrz7ma6vrltud57q_761c4f57dfed11ac.jpg" alt="\u5f20\u827a\u5174\u7528\u884c\u52a8\u545b\u97e9\u56fd\u7f51\u53cb\uff1a\u8bf4\u4e2d\u6587\uff0c\u56e0\u4e3a\u6211\u662f\u4e2d\u56fd\u4eba\uff01"><br></p>\n <p>\u5982\u679c\u56fd\u5bb6\u4e4b\u95f4\u56e0\u4e3a\u8bed\u8a00\u7684\u95ee\u9898\u5c31\u5404\u79cd\u9488\u5bf9\uff0c\u90a3\u4e5f\u6ca1\u4ec0\u4e48\u597d\u76f8\u5904\u7684</p>\n <p><img src="//pic1.58cdn.com ...
#      u'digest': None,
#      u'id': 2683262,
#      u'newsfrom': None,
#      u'newsparams': None,
#      u'newstype': 0,
#      u'pic': u'//pic1.58cdn.com.cn/p1/small/n_v1bj3gzsb7ma6vryfuw4uq_e219ad2f289ed6de.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bj3gzsb7ma6vrypmcrmq_e219ad2f289ed6de.gif|//pic1.58cdn.com.cn/p1/small/n_v1bj3gzrz7ma6vqfknaa5a_761c4f57dfed11ac.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwwj7ma6vrizr5niq_6666f81f38fd44ce.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkb7ma6vqqkjpzta_d016075a4f426d09.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bj3gzsb7ma6vqxmwqj3q_e219ad2f289ed6de.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkj7ma6vrdhvcm5a_d016075a4f426d09.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bj3gzrz7ma6vrltud57q_761c4f57dfed11ac.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkb7ma6vqg3zdbzq_d016075a4f426d09.jpg',
#      u'sortid': 0,
#      u'source': u'\u8001\u53f8\u673a\u661f\u7237',
#      u'state': True,
#      u'tag': u'\u5a31\u4e50',
#      u'tags': [],
#      u'title': u'\u5f20\u827a\u5174\u7528\u884c\u52a8\u545b\u97e9\u56fd\u7f51\u53cb\uff1a\u8bf4\u4e2d\u6587\uff0c\u56e0\u4e3a\u6211\u662f\u4e2d\u56fd\u4eba\uff01',
#      u'type': u't_toutiao',
#      u'url': None},
#     u'_type': u't_toutiao'},
#    {u'_id': u'2945585',
#     u'_index': u'dbwww58com',
#     u'_score': 128.48442,
#     u'_source': {u'@timestamp': u'2016-12-20T07:16:05.379Z',
#      u'@version': u'1',
#      u'addtime': u'2016-12-09T13:59:43.000Z',
#      u'author': None,
#      u'channel': 0,
#      u'cityid': 0,
#      u'content': u'<img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzsgpxbffq6x5h42a_e219ad2f289ed6de.jpg">\n<p></p>\n<p>\u4eca\u5929\u6709\u7f51\u53cb\u7206\u6599\uff0c\u300a\u6781\u9650\u6311\u6218\u300b\u7b2c\u4e09\u5b63\u6b63\u5728\u62cd\u6444\uff0c\u4f46\u662f\u5728\u62cd\u6444\u73b0\u573a\u6ca1\u6709\u770b\u5230\u5f20\u827a\u5174\uff0c\u4f46\u662f\u51fa\u73b0\u4e86\u65b0\u7684\u9762\u5b54\uff0c\u90a3\u5c31\u662f\u4eca\u5e74\u706b\u7684\u4e00\u584c\u7cca\u6d82\u7684\u6768\u6d0b\uff0c\u5f88\u591a\u7f51\u53cb\u62c5\u5fc3\u6768\u6d0b\u628a\u5f20\u827a\u5174\u9876\u66ff\u4e86\u3002</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwwopxbffqxpgqiqq_6666f81f38fd44ce.jpg">\n<p></p>\n<p>\u56e0\u4e3a\u4eca\u5e74\u9650\u97e9\u4ee4\u7684\u539f\u56e0\uff0c\u5f20\u827a\u5174\u53c8\u662f\u97e9\u56fdEXO\u7537\u56e2\u7684\u4e3b\u8981\u6210\u5458\uff0c\u90a3\u5f20\u827a\u5174\u4f1a\u4e0d\u4f1a\u53d7\u5230\u9650\u97e9\u4ee4\u7684\u5f71\u54cd\u5462\uff1f\u8fd9\u6b21\u6ca1\u6709\u89c1\u5230\u5f20\u827a\u5174\uff0c\u5f88\u591a\u6781\u9650\u6311\u6218\u7684\u7c89\u4e1d\u5c31\u6bd4\u8f83\u62c5\u5fc3\u662f\u4e0d\u662f\u9000\u51fa\u4e86\u3002</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwkgpxbffrtxj6fqa_d016075a4f426d09.jpg">\n<p></p>\n<p>\u5c0f\u7f16\u611f\u89c9\u8fd9\u79cd\u60c5\u51b5\u5e94\u8be5\u4e0d\u4f1a\u53d1\u751f\u7684\uff0c\u9650\u97e9\u4ee4\u6bd5\u7adf\u662f\u9650\u5236\u7684\u97e9\u56fd\u827a\u4eba\uff0c\u5f20\u827a\u5174\u867d\u7136\u662f\u97e9\u56fdEXO\u7684\u6210\u5458\uff0c\u4f46\u662f\u5f20\u827a\u5174\u5df2\u7ecf\u6210\u7acb\u4e86\u81ea\u5df1\u7684\u5de5\u4f5c\u5ba4\uff0c\u5e76\u4e14\u4e2d\u56fd\u7684\u6240\u6709\u6f14\u827a\u4e8b\u4e1a\u90fd\u6709\u81ea\u5df1\u6253\u7406\uff0c\u548c\u97e9\u56fd\u6ca1\u6709\u4efb\u4f55\u5173\u7cfb\u4e86\u3002</p>\n<img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwkopxbffrszbsaha_d016075a4f426d09.jpg">\n<p></p>\n<div id="hidtag"></div>\n<p>\u800c\u4e14\u5f20\u827a\u5174\u662f\u4e00\u4e2a\u7279\u522b\u7231\u56fd\u7684\u827a\u4eba\uff0c\u76f8\u4fe1\u5f20\u827a\u5174\u4e00\u5b9a\u4f1a\u51fa\u73b0\u5728\u300a\u6781\u9650\u6311\u6218\u300b\u7b2c\u4e09\u5b63\u7684\u821e\u53f0\u4e0a\u7684\uff0c\u6768\u6d0b\u53ef\u80fd\u662f\u4f5c\u4e3a\u5609\u5bbe\u53c2\u4e0e\u300a\u6781\u9650\u6311\u6218\u300b\u7684\u5f55\u5236\uff0c\u81f3\u4e8e\u5f20\u827a\u5174\u4e3a\u4ec0\u4e48\u6ca1\u6709\u51fa\u73b0\u5728\u5f55\u5236\u73b0\u573a\uff0c\u53ef\u80fd\u662f\u6709\u5176\u4ed6\u4e8b\u60c5\uff0c\u6216\u8005\u5df2\u7ecf\u5728\u73b0\u573a\uff0c\u4f46\u662f\u6ca1\u6709\u88ab\u62cd\u5230\uff1f\u5e0c\u671b\u5982\u6b64\u5427\uff0c\u771f\u4e0d\u5e0c\u671b\u6781\u9650\u6311\u6218\u7537\u4eba\u5e2e\u5206\u5f00\u554a\u3002</p>',
#      u'digest': None,
#      u'id': 2945585,
#      u'newsfrom': None,
#      u'newsparams': None,
#      u'newstype': 0,
#      u'pic': u'//pic1.58cdn.com.cn/p1/small/n_v1bj3gzsgpxbffq6x5h42a_e219ad2f289ed6de.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwwopxbffqxpgqiqq_6666f81f38fd44ce.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkgpxbffrtxj6fqa_d016075a4f426d09.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkopxbffrszbsaha_d016075a4f426d09.jpg',
#      u'sortid': 0,
#      u'source': u'\u5a31\u4e50summer',
#      u'state': True,
#      u'tag': u'\u5a31\u4e50 \u9650\u97e9\u4ee4 \u5f20\u827a\u5174 \u660e\u661f \u6781\u9650\u6311\u6218 \u6768\u6d0b',
#      u'tags': [],
#      u'title': u'\u7f51\u66dd\u6768\u6d0b\u52a0\u5165\u300a\u6781\u9650\u6311\u6218\u300b, \u5f20\u827a\u5174\u53d7\u9650\u97e9\u4ee4\u5f71\u54cd\u9000\u51fa?',
#      u'type': u't_toutiao',
#      u'url': None},
#     u'_type': u't_toutiao'},
#    {u'_id': u'2712033',
#     u'_index': u'dbwww58com',
#     u'_score': 128.41344,
#     u'_source': {u'@timestamp': u'2016-12-20T06:35:07.682Z',
#      u'@version': u'1',
#      u'addtime': u'2016-11-30T11:44:34.000Z',
#      u'author': None,
#      u'channel': 0,
#      u'cityid': 0,
#      u'content': u'<div>\n <p>\u7537\u660e\u661f\u62b1\u5a03</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwkncxm7frs4ygeja_d016075a4f426d09.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwtndxm7frmeuxrrq_6c7ea76f39c78102.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p>\u5c4b\u91cc\u97ec</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwxvcxm7fr5z2zyna_c5e82e3eff7fcb9a.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p>\u7ee7\u79d1</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzsfcxm7fr2thtfiq_e219ad2f289ed6de.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p>\u91d1\u79c0\u8d24</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwkfcxm7frgrldjbq_d016075a4f426d09.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p>\u8001\u5e72\u90e8</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzsfcxm7frf4snjia_e219ad2f289ed6de.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p>\u51ef\u51ef\u738b</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bkuyfvncxm7fraqedjsq_4efbf870af0a0e2d.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p>\u9648\u6653</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwxvcxm7fqfdedi2q_c5e82e3eff7fcb9a.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwkfcxm7fr7rmvbla_d016075a4f426d09.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p>\u6613\u70ca\u5343\u73ba</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bkuymc5cxm7fqgow4yja_55b683d383d7d405.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p>\u859b\u4e4b\u8c26</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bl2lwwncxm7fqdmhxqia_6666f81f38fd44ce.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p>\u5b8b\u4ef2\u57fa</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bkuyfvncxm7fr632nqiq_4efbf870af0a0e2d.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p>\u5468\u6770\u4f26</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bkuyfvncxm7fqbbera7a_4efbf870af0a0e2d.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bkuymc5cxm7fqsem74lq_55b683d383d7d405.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p>\u9648\u4f1f\u9706</p>\n <p><img src="//pic1.58cdn.com.cn/p1/big/n_v1bj3gzsfcxm7frpyztv2a_e219ad2f289ed6de.jpg" alt="\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4"><br></p>\n <p>\u7ec8\u4e8e\u5b66\u4f1a\u4e86\u6b63\u786e\u62b1\u6cd5</p>\n <p><img src= ...
#      u'digest': None,
#      u'id': 2712033,
#      u'newsfrom': None,
#      u'newsparams': None,
#      u'newstype': 0,
#      u'pic': u'//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkncxm7frs4ygeja_d016075a4f426d09.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwtndxm7frmeuxrrq_6c7ea76f39c78102.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwxvcxm7fr5z2zyna_c5e82e3eff7fcb9a.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bj3gzsfcxm7fr2thtfiq_e219ad2f289ed6de.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkfcxm7frgrldjbq_d016075a4f426d09.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bj3gzsfcxm7frf4snjia_e219ad2f289ed6de.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bkuyfvncxm7fraqedjsq_4efbf870af0a0e2d.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwxvcxm7fqfdedi2q_c5e82e3eff7fcb9a.jpg|//pic1.58cdn.com.cn/p1/small/n_v1bl2lwkfcxm7fr7rmvbla_d016075a4f426d09.jpg',
#      u'sortid': 0,
#      u'source': u'\u5a31\u4e50\u524d\u54e8\u6218',
#      u'state': True,
#      u'tag': u'\u5a31\u4e50',
#      u'tags': [],
#      u'title': u'\u7537\u660e\u661f\u62b1\u5a03\uff0c\u6613\u70ca\u5343\u73ba\u597d\u719f\u7ec3\uff0c\u6768\u6d0b\u5f20\u827a\u5174\u597d\u6e29\u67d4',
#      u'type': u't_toutiao',
#      u'url': None},
#     u'_type': u't_toutiao'}],
#   u'max_score': 129.552,
#   u'total': 189567},
#  u'timed_out': False,
#  u'took': 33}

# %%
from starbase import Connection
c = Connection()
c.tables(10.126.101.7:8000)

'''
t = c.table('table3')
t.create('column1', 'column2', 'column3')
t.exists()
t.columns()
t.add_columns('column4', 'column5', 'column6', 'column7')
t.drop_columns('column6', 'column7')
t.drop()
'''
# Out:
# "\nt = c.table('table3')\nt.create('column1', 'column2', 'column3')\nt.exists()\nt.columns()\nt.add_columns('column4', 'column5', 'column6', 'column7')\nt.drop_columns('column6', 'column7')\nt.drop()\n"

# %%
class ES(object):
    @classmethod
    def connect_host(cls):
        hosts=[{"host": "xx.xxx.x.xx"},
                {"host": "xx.xxx.x.xx"},
                {"host": "xx.xxx.x.xx"},
                {"host": "xx.xxx.x.xx"},]
        es = elasticsearch.Elasticsearch(
            hosts,
            sniff_on_start=True,
            sniff_on_connection_fail=True,
            sniffer_timeout=600
        )
        return es
    
    def es_query(domain="", start=None, end=None, reverse=False, limit_cnt=20, category=0):
    es = ES.connect_host()
    now = datetime.datetime.now()
    if reverse:
        order = "desc"
    else:
        order = "asc"
    if not start:
        start = now - datetime.timedelta(weeks=2000)
    if not end:
        end = now
    range_body = {
        "range": {
            "time": {
                "gte": start,
                "lte": end
            }
        }
    }
    and_list = [range_body]
    domain_body = {
        "term": {
            "domain": domain
        }
    }
    category_body = {
        "term": {
            "category": category
        }
    }
    if domain:
        and_list.append(domain_body)
    if category:
        and_list.append(category_body)
    q_body = {
        "size": limit_cnt,
        "sort": [
            {
                "time": {
                    "order": order
                }
            }
        ],
        "query": {
            "filtered": {
                "query": {"matchAll": {}},
                "filter": {
                    "and": and_list
                }
            }
        }
    }
    res = es.search(body=q_body)
    ret = []
    for hit in res["hits"]["hits"]:
        value = {}
        src = hit["_source"]
        if src:
            try:
                the_time = src["time"]
                if len(the_time) < 20:
                    value["time"] = datetime.datetime.strptime(the_time, "%Y-%m-%dT%H:%M:%S")
                else:
                    value["time"] = datetime.datetime.strptime(the_time, "%Y-%m-%dT%H:%M:%S.%f")
                ret.append(value)
            except Exception as e:
                print str(e)
                ret = []
                print "Query xxxxx data failed!"
    return ret
